# %% [markdown]
# <a href="https://colab.research.google.com/github/paulo-santos-ds/br-python-challenges/blob/master/Desafio_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Desafio 8
#
# Escreva um script Python para encontrar as 10 palavras mais longas em um arquivo de texto.
# O arquivo .txt está localizado na mesma pasta do projeto (**texto.txt**).

# %%
# Seu código

# %%
with open('/content/exercicio_08.txt', 'r') as f:
    dic = {}    
    conteudo = f.read().replace('.', ' ').replace('-', ' ').replace(',', ' ').replace(')', ' ')
    for palavra in conteudo.split():
        dic[f'{palavra}'] = len(palavra)
        ordem = sorted(dic.items(), key=itemgetter(1), reverse=True)
    for k, v in enumerate(ordem):
        if k < 10:
            print(v[0], v[1])
# Out:
# comprehensive 13
# intermediate 12
# interpreted 11
# programming 11
# readability 11
# programmers 11
# philosophy 10
# emphasizes 10
# imperative 10
# functional 10
